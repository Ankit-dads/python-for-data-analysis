# %% [markdown]
# # what is string

# %%
first_way = """Ankit"""
print(first_way)
print(type(first_way))
# Out:
# Ankit
# <class 'str'>

# %%
text = "i love trading"
print(text)
# Out:
# i love trading

# %%
print(text.capitalize()) # capatalize will capital the fist letter of the string
# Out:
# I love trading

# %%
print((text.title())) # title will make fist letter captital
# Out:
# I Love Trading

# %%
print(text.upper()) # upper will make each letter capital
# Out:
# I LOVE TRADING

# %%
print(text.casefold()) # both lower and casefold are used to lower character but.....
# Out:
# i love trading

# %%
t = text.lower()
print(t)
# Out:
# i love trading

# %% [markdown]
# * what is the diff btw casefold and lower

# %%
# casefold will also lower special character while lower doesn't

# %%
A = "ß"
p = A.lower()
print(p)

b = A.casefold()
print(b)
# Out:
# ß
# ss

# %%
name = "Ankit kashyap"
print(name)
# Out:
# Ankit kashyap

# %%
print(name.center(30,">")) # center will give center string with specific length
# Out:
# >>>>>>>>Ankit kashyap>>>>>>>>>

# %%
x = ">>>>>>>>Ankit kashyap>>>>>>>>>"
len(x)
# Out:
# 30

# %%
print(name.ljust(54,"2"))
# Out:
# Ankit kashyap22222222222222222222222222222222222222222

# %%
print(name.rjust(40,'<'))
# Out:
# <<<<<<<<<<<<<<<<<<<<<<<<<<<Ankit kashyap

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(name)
# Out:
# Ankit kashyap

# %%
name.find('s') # it will find the first foremost value from the left side| and give -1 for any value which is not present in the string
# Out:
# 8

# %%
print(name[4]) # this will find the index of the string
print(name[6])
print(name[3])
print(name[8])
# Out:
# t
# k
# i
# s

# %%
print(name)
print(name[-6]) # in reverse order it will count from -1 not from zero means the first element is count/index as 1 not 0
print(name[-3])
print(name[-5])
# Out:
# Ankit kashyap
# a
# y
# s

# %%
Name = 'programming'
print(Name)
# Out:
# programming

# %%
Name
# Out:
# 'programming'

# %%
print(Name.index("g")) # index will give the index of substring/string character
# Out:
# 3

# %%
name1 = 'Dipanshi'
print(name1)
# Out:
# Dipanshi

# %%
print(name1.rfind('i'), ' ',
name1.find('i'))
# Out:
# 7   1

# %%
print(name1.rindex('i'))
# Out:
# 7

# %%
print(name1.index('i'))
# Out:
# 1

# %%
print(text)
# Out:
# i love trading

# %%
text.replace('i','I')
# Out:
# 'I love tradIng'

# %%
text.split('love')
# Out:
# ['i ', ' trading']

# %%
text.split() # if no value pass it will separate the string on the basis of space
# Out:
# ['i', 'love', 'trading']

# %%
txt = "hello, my name is Peter, I am 26 years old"

x = txt.split(", ")

print(x)
# Out:
# ['hello', 'my name is Peter', 'I am 26 years old']

# %%
txt = "apple#banana#cherry#orange"

x = txt.split("#")

print(x)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
name2 = "dipanshi bhasin"

# %%
print(name2.partition('a'))
# Out:
# ('dip', 'a', 'nshi bhasin')

# %%
print(name2.rpartition('a'))
# Out:
# ('dipanshi bh', 'a', 'sin')

# %%
print(name2.split('h'))
# Out:
# ['dipans', 'i b', 'asin']

# %%
print(name2.split())
# Out:
# ['dipanshi', 'bhasin']

# %%
print(dir(str))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
print(dir(tuple))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
print(dir(dict))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
NAME = "Niharika bhasin"
age = 24
print("my name is", NAME , 'and i am',age , 'years old')
# Out:
# my name is Niharika bhasin and i am 24 years old

# %% [markdown]
# # F string (formatted string)

# %%
print(f"my name is {name} and i am {age} years old")
# Out:
# my name is Ankit kashyap and i am 24 years old

# %% [markdown]
# ## Slicing

# %%
print(text)
# Out:
# i love trading

# %%
text.find('a')
# Out:
# 9

# %%
text.rfind('i') # it will give the value from the right side with default index no.
# Out:
# 11

# %%
text[::-1] # start, stop, step
# Out:
# 'gnidart evol i'

# %%
text[1:10:2]
# Out:
# ' oeta'

# %%
print(len(text))
# Out:
# 14
