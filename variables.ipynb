# %%
name = 'Ankit'

print(name)
print(id(name))
# Out:
# Ankit
# 2223366244176

# %%
x = 10  # same values have same id location.
print(id(x))
y = 10
print(id(y))
# Out:
# 140712467006872
# 140712467006872

# %% [markdown]
# # Rules for variable

# %% [markdown]
# # it can't start with a number

# %%
15 = 'ankit'
print(15)
# Out:
#   Cell In[3], line 1
#     15 = 'ankit'
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ## can't use special char and space

# %%
name@ = "ankit"
print(name@)
# Out:
#   Cell In[4], line 1
#     name@ = "ankit"
#           ^
# SyntaxError: invalid syntax

# %%
# python is a case sensitive language it treats small and capital letter different

# %%
# can't be keywords
## reserved keywords
## not should be a variable name, file, function, class name

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
if = "ankit"
print(if)
# Out:
#   Cell In[1], line 1
#     if = "ankit"
#        ^
# SyntaxError: invalid syntax

# %%
# that all about variables
# Thanks
